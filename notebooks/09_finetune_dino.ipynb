# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# d:\code\FSFM_Lite_Project

# %%
from pathlib import Path
import sys
import time

import pandas as pd
import torch
import torch.nn as nn

from torch.utils.data import (
    DataLoader,
    random_split
)

from torchvision import transforms
from tqdm import tqdm

from src.datasets.celeba_spoof_dataset import (
    CelebASpoofDataset
)

from src.models.fsfm_lite import (
    FSFMLite
)

# %%
PROJECT_ROOT = Path(
    "/kaggle/input/datasets/thanhluanchimto/source-code"
)

METADATA_ROOT = Path(
    "/kaggle/input/datasets/thanhluanchimto/meta-data/metadata"
)

DATA_ROOT = Path(
    "/kaggle/input/datasets/attentionlayer241/celeba-spoof-for-face-antispoofing/CelebA_Spoof_/CelebA_Spoof"
)

MODEL_PATH = Path(
    "/kaggle/input/datasets/thanhluanchimto/models/best_fsfm_lite.pth"
)

CHECKPOINT_ROOT = (
    Path("/kaggle/working")
    / "finetune_checkpoints"
)

CHECKPOINT_ROOT.mkdir(
    parents=True,
    exist_ok=True
)

sys.path.append(
    str(PROJECT_ROOT)
)

# %%
train_df = pd.read_csv(
    METADATA_ROOT / "train_df.csv"
)

print(train_df.shape)
